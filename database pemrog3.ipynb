# %%
# !pip install pymysql
# !service mysql start
# Out:
# ...
#  * Starting MySQL database server mysqld
#    ...done.

# %%
# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED WITH mysql_native_password BY ''"

# %%
# !mysql  -u root -p '' -e "CREATE DATABASE db_emp"
# Out:
# Enter password:

# %%
import pymysql.cursors

db = pymysql.connect(host='127.0.0.1',user="root",password="",database='db_emp',charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor)
print("Connection to MySQL database successful!")
# Out:
# Connection to MySQL database successful!
